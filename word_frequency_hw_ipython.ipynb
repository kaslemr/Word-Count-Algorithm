# %%
with open ("sample.txt") as infile:
    book = infile.read()

# %%
import string
import re
text = "hi this is my store. This is my store, This is my store."

for words in text:
    split_text = text.split()
    print(split_text)
    break
# Out:
# ['hi', 'this', 'is', 'my', 'store.', 'This', 'is', 'my', 'store,', 'This', 'is', 'my', 'store.']

# %%
#def clean_sentence(sentence):
    new_sentence = ""
    for letter in sentence:
        if letter not in '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~':
            new_sentence += letter
    return(new_sentence)

#def remove_whitespace(sentence):
    new_sentence = ""
    for letter in sentence:
        if letter != '\n':
            new_sentence += letter
    return(new_sentence)

#clean_sentence(book)
#remove_whitespace(book)
#book.split()

# %%
def clean_sentence(sentence):
    new_sentence = ""
    for letter in sentence:
        if letter not in '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~': 
            new_sentence += letter
    return new_sentence

def strip_book(text):
    text = clean_sentence(text)
    text = text.lower()
    text = text.split()
    return text

book_dictionary = {}
def count_words(book):
    for word in book:
        if word in book_dictionary.keys():
            book_dictionary[word] += 1
        else:
            book_dictionary[word] = 1
    print(book_dictionary)

book = clean_sentence(book)
book = strip_book(book)
book = count_words(book)
print(book)
# Out:
# {'inclined': 2, 'goodmorning': 4, 'instead': 5, 'separating': 1, 'recalled': 2, 'consulting': 2, 'outlook': 1, 'penetrated': 1, 'knocked': 1, 'interrogate': 1, 'payments': 3, 'inadequate': 1, 'friends': 20, 'eyeseyes': 1, 'lattice': 1, 'people': 25, 'approbation': 1, 'blotched': 1, 'correct': 3, 'modest': 1, 'checkmated': 1, 'deadened': 1, 'eleven': 1, 'displayed': 1, 'vigil': 2, 'debt': 1, 'ill': 17, 'deceived': 3, 'suggests': 1, 'year': 3, 'fiends': 1, 'lioness': 1, 'immaterial': 1, 'cease': 1, 'supposed': 3, 'pedestal': 1, 'worked': 2, 'seldom': 6, 'crawl': 1, 'bared': 1, 'research': 2, 'loud': 2, 'here': 89, 'musical': 1, 'dr': 107, 'leanjawed': 3, 'selfish': 1, 'fourth': 2, 'inexorably': 1, 'alternative': 4, 'corrupt': 1, 'rising': 7, 'discuss': 2, 'clipped': 3, 'dispose': 1, 'follow': 10, 'winds': 1, 'implicate': 1, 'determined': 3, 'driver': 5, '2852txt': 1, 'plume': 2, 'bramble': 1, 'example': 11, 'status': 4, 'teach': 2, 'weighing': 1, 'said': 240, 'firstclass': 2, 'worse': 3, 'ross': 1, 'matter': 49, 'coachman': 1, 'seem': 14, 'step': 8, 'entered': 7, 'seewhy': 1, 'sprinkled': 1, 'mrcs': 3, 'stick': 15, 'spoilsport': 1, 'summons': 1, 'covet': 1, 'i': 1465, 'flaxenhaired': 1, 'tomorrow': 11, 'fastened': 2, 'smoke': 7, 'baying': 2, 'near': 17, 'talk': 11, 'prepared': 6, 'draped': 1, 'exercised': 1, 'methods': 5, 'pasted': 2, 'chuckles': 1, 'yours': 7, 'fancies': 1, 'circumspect': 1, 'wicked': 7, 'parishes': 1, 'brick': 1, 'pathology': 1, 'six': 5, 'read': 22, 'else': 15, 'wanting': 1, 'distribute': 6, 'warrant': 1, 'tracery': 1, 'pound': 1, 'trembling': 3, 'freckles': 1, 'negro': 2, 'lisp': 1, 'nets': 4, 'attempting': 1, 'treat': 1, 'eyes': 69, 'stapletons': 22, 'yorkshire': 2, 'farm': 3, 'wicketgate': 4, 'examination': 3, 'men': 14, 'usthe': 1, 'minds': 6, 'fall': 5, 'murders': 1, 'turpey': 1, 'alton': 1, 'stole': 2, 'argue': 1, 'knee': 3, 'distance': 14, 'slumbered': 1, 'grassgrown': 1, 'mastiff': 3, 'delighted': 1, 'ferocity': 1, 'hellhound': 3, 'trust': 9, 'eight': 1, 'donations': 16, 'yew': 12, 'bitterly': 5, 'modification': 1, 'legally': 1, 'exciting': 1, 'observations': 2, 'incidents': 5, 'lisping': 1, 'pitt': 1, 'battle': 1, 'carry': 10, 'thickly': 4, 'anywhere': 5, 'impossible': 8, 'her': 163, 'trembled': 1, 'intolerant': 1, 'hartstongue': 1, 'lancet': 1, 'smart': 1, 'sooner': 5, 'rueful': 3, 'tastes': 4, 'fate': 5, 'unknown': 7, 'peered': 1, 'cairns': 1, 'home': 22, 'shipleys': 1, 'moonlight': 4, 'manner': 8, 'scuffling': 1, 'permanently': 1, 'police': 9, 'fluttered': 2, 'gone': 24, 'acquired': 1, 'henrys': 9, 'imagination': 3, 'gum': 2, 'austere': 1, 'les': 1, 'telling': 6, 'fellow': 33, 'awaiting': 2, 'shelf': 1, 'ears': 8, 'head': 32, 'inherit': 1, 'trifling': 1, 'onehalf': 1, 'sturdily': 1, 'reality': 1, 'violates': 1, 'flaring': 1, 'views': 2, 'belonged': 2, 'heartily': 1, 'fairy': 1, 'wanton': 2, 'writhing': 1, 'passed': 31, 'usually': 3, 'progress': 3, 'scarred': 1, 'rascal': 2, 'wheels': 5, 'bulk': 1, 'rolling': 4, 'depends': 5, 'famous': 3, 'investigations': 2, 'landscape': 2, 'arch': 1, 'balanced': 1, 'soared': 1, '1e5': 1, 'infernal': 2, 'comparative': 2, 'salt': 1, 'quoted': 3, 'vatican': 1, 'cobs': 1, 'threads': 4, 'dreary': 2, 'outburst': 2, 'gods': 3, 'sentimental': 1, 'desired': 2, 'complete': 13, 'pictured': 1, 'gleaming': 2, 'beyond': 12, 'horribly': 1, 'waste': 3, 'surprised': 13, 'farrier': 1, 'ablebut': 1, 'maximum': 1, 'pools': 1, 'america': 6, 'shared': 3, 'masked': 1, 'thankfulness': 1, 'wrong': 8, 'odds': 2, 'cleverness': 1, 'shadowed': 3, 'tone': 2, 'instructions': 4, 'arise': 2, 'perfectly': 7, 'fixture': 2, 'explanatory': 1, 'gained': 1, 'originally': 1, 'physical': 4, 'moderate': 1, 'agile': 1, 'outdated': 1, 'wavering': 1, 'repaired': 1, 'redfaced': 2, 'succession': 3, 'trifle': 2, 'expenses': 4, 'defended': 1, 'cried': 31, 'huge': 17, 'skeleton': 1, 'strikinglooking': 1, 'shadow': 11, 'decanter': 1, 'vicious': 1, 'unannounced': 1, 'used': 15, 'henrysthe': 1, 'net': 7, 'gather':  ...
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-280-0426df688db4> in <module>()
# ----> 1 print(max(book, key=said.get))
#
# NameError: name 'said' is not defined

# %%
# Out:
#   File "<ipython-input-217-273550836525>", line 7
#     book_dictionary[word] += 1
#     ^
# IndentationError: unexpected indent
